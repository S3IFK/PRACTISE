# %% [markdown]
# <a href="https://colab.research.google.com/github/S3IFK/Practise/blob/main/CNN_Build_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# batch, classes, epochs
batch_size = 32
num_classes = 10
epochs = 50

# %%
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# plotting some random 10 images
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = x_train[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = (features_idx[img_num,::])
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
# Convert class vectors to binary class matrices.
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# model architecture
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
# summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  activation_1 (Activation)   (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  activation_2 (Activation)   (None, 15, 15, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# convert to float, normalise the data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
# train 
model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 289s 184ms/step - loss: 2.1196 - accuracy: 0.2060 - val_loss: 2.1098 - val_accuracy: 0.2459
# Epoch 2/50
# 1563/1563 [==============================] - 292s 187ms/step - loss: 1.8293 - accuracy: 0.3384 - val_loss: 1.6273 - val_accuracy: 0.4055
# Epoch 3/50
# 1563/1563 [==============================] - 289s 185ms/step - loss: 1.5896 - accuracy: 0.4212 - val_loss: 1.4360 - val_accuracy: 0.4779
# Epoch 4/50
# 1563/1563 [==============================] - 305s 195ms/step - loss: 1.4551 - accuracy: 0.4728 - val_loss: 1.3279 - val_accuracy: 0.5229
# Epoch 5/50
# 1563/1563 [==============================] - 287s 184ms/step - loss: 1.3521 - accuracy: 0.5108 - val_loss: 1.2367 - val_accuracy: 0.5550
# Epoch 6/50
# 1563/1563 [==============================] - 285s 183ms/step - loss: 1.2818 - accuracy: 0.5419 - val_loss: 1.1712 - val_accuracy: 0.5837
# Epoch 7/50
# 1563/1563 [==============================] - 291s 186ms/step - loss: 1.2190 - accuracy: 0.5649 - val_loss: 1.1571 - val_accuracy: 0.5850
# Epoch 8/50
# 1563/1563 [==============================] - 282s 180ms/step - loss: 1.1625 - accuracy: 0.5881 - val_loss: 1.0668 - val_accuracy: 0.6177
# Epoch 9/50
# 1563/1563 [==============================] - 301s 192ms/step - loss: 1.1146 - accuracy: 0.6041 - val_loss: 1.0083 - val_accuracy: 0.6453
# Epoch 10/50
# 1563/1563 [==============================] - 292s 187ms/step - loss: 1.0755 - accuracy: 0.6180 - val_loss: 0.9739 - val_accuracy: 0.6574
# Epoch 11/50
# 1563/1563 [==============================] - 284s 182ms/step - loss: 1.0349 - accuracy: 0.6335 - val_loss: 0.9664 - val_accuracy: 0.6604
# Epoch 12/50
# 1563/1563 [==============================] - 292s 187ms/step - loss: 0.9966 - accuracy: 0.6458 - val_loss: 0.9095 - val_accuracy: 0.6790
# Epoch 13/50
# 1563/1563 [==============================] - 293s 188ms/step - loss: 0.9686 - accuracy: 0.6581 - val_loss: 0.8857 - val_accuracy: 0.6961
# Epoch 14/50
# 1563/1563 [==============================] - 294s 188ms/step - loss: 0.9352 - accuracy: 0.6674 - val_loss: 0.8998 - val_accuracy: 0.6887
# Epoch 15/50
# 1563/1563 [==============================] - 286s 183ms/step - loss: 0.9095 - accuracy: 0.6796 - val_loss: 0.8691 - val_accuracy: 0.6975
# Epoch 16/50
# 1563/1563 [==============================] - 290s 185ms/step - loss: 0.8857 - accuracy: 0.6878 - val_loss: 0.8306 - val_accuracy: 0.7153
# Epoch 17/50
# 1563/1563 [==============================] - 291s 186ms/step - loss: 0.8668 - accuracy: 0.6942 - val_loss: 0.8273 - val_accuracy: 0.7117
# Epoch 18/50
# 1563/1563 [==============================] - 283s 181ms/step - loss: 0.8395 - accuracy: 0.7022 - val_loss: 0.7843 - val_accuracy: 0.7305
# Epoch 19/50
# 1563/1563 [==============================] - 292s 187ms/step - loss: 0.8168 - accuracy: 0.7122 - val_loss: 0.7957 - val_accuracy: 0.7230
# Epoch 20/50
# 1563/1563 [==============================] - 292s 187ms/step - loss: 0.7998 - accuracy: 0.7192 - val_loss: 0.7726 - val_accuracy: 0.7301
# Epoch 21/50
# 1563/1563 [==============================] - 294s 188ms/step - loss: 0.7813 - accuracy: 0.7258 - val_loss: 0.7998 - val_accuracy: 0.7224
# Epoch 22/50
# 1563/1563 [==============================] - 283s 181ms/step - loss: 0.7613 - accuracy: 0.7321 - val_loss: 0.7449 - val_accuracy: 0.7435
# Epoch 23/50
# 1563/1563 [==============================] - 290s 186ms/step - loss: 0.7429 - accuracy: 0.7387 - val_loss: 0.7206 - val_accuracy: 0.7528
# Epoch 24/50
# 1563/1563 [==============================] - 290s 185ms/step - loss: 0.7267 - accuracy: 0.7445 - val_loss: 0.7170 - val_accuracy: 0.7546
# Epoch 25/50
# 1563/1563 [==============================] - 295s 189ms/step - loss: 0.7135 - accuracy: 0.7483 - val_loss: 0.6956 - val_accuracy: 0.7602
# Epoch 26/50
# 1563/1563 [==============================] - 293s 187ms/step - loss: 0.6883 - accuracy: 0.7573 - val_loss: 0.6840 - val_accuracy: 0.7658
# Epoch 27/50
# 1563/1563 [==============================] - 297s 190ms/step - loss: 0.6767 - accuracy: 0.7609 - val_loss: 0.6794 - val_accuracy: 0.7644
# Epoch 28/50
# 1563/1563 [==============================] - 302s 193ms/step - loss: 0.6670 - accuracy: 0.7659 - val_loss: 0.6917 - val_accuracy: 0.7634
# Epoch 29/50
# 1563/1563 [==============================] - 292s 187ms/step - loss: 0.6505 - accuracy: 0.7713 - val_loss: 0.7003 - val_accuracy: 0.7601
# Epoch 30/50
# 1563/1563 [==============================] - 293s 187ms/step - loss: 0.6390 - accuracy: 0.7741 - val_loss: 0.6697 - val_accuracy: 0.7685
# Epoch 31/50
# 1563/1563 [==============================] - 284s 182ms/step - loss: 0.6192 - accuracy: 0.7813 - val_loss: 0.6994 - val_accuracy: 0.7633
# Epoch 32/50
# 1563/1563 [==============================] - 284s 182ms/step - loss: 0.6124 - accuracy: 0.7830 - val_loss: 0.6592 - val_accuracy: 0.7756
# Epoch 33/50
# 1563/1563 [==============================] - 283s 181ms/step - loss: 0.6040 - accuracy: 0.7866 - val_loss: 0.6722 - val_accuracy: 0.7705
# Epoch 34/50
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.5828 - accuracy: 0.7946 - val_loss: 0.6515 - val_accuracy: 0.7747
# Epoch 35/50
# 1563/1563 [==============================] - 292s 187ms/step - loss: 0.5760 - accuracy: 0.7959 - val_loss: 0.6487 - val_accuracy: 0.7779
# Epoch 36/50
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.5665 - accuracy: 0.7998 - val_loss: 0.6407 - val_accuracy: 0.7795
# Epoch 37/50
# 1563/1563 [==============================] - 283s 181ms/step - loss: 0.5510 - accuracy: 0.8045 - val_loss: 0.6509 - val_accuracy: 0.7815
# Epoch 38/50
# 1563/1563 [==============================] - 293s 187ms/step - loss: 0.5437 - accuracy: 0.8091 - val_loss: 0.6160 - val_accuracy: 0.7887
# Epoch 39/50
# 1563/1563 [==============================] - 295s 189ms/step - loss: 0.5338 - accuracy: 0.8095 - val_loss: 0.6319 - val_accuracy: 0.7817
# Epoch 40/50
# 1563/1563 [==============================] - 295s 189ms/step - loss: 0.5207 - accuracy: 0.8146 - val_loss: 0.6274 - val_accuracy: 0.7834
# Epoch 41/50
# 1563/1563 [==============================] - 286s 183ms/step - loss: 0.5091 - accuracy: 0.8184 - val_loss: 0.6197 - val_accuracy: 0.7901
# Epoch 42/50
# 1563/1563 [==============================] - 293s 187ms/step - loss: 0.5028 - accuracy: 0.8224 - val_loss: 0.6107 - val_accuracy: 0.7894
# Epoch 43/50
# 1563/1563 [==============================] - 294s 188ms/step - loss: 0.4914 - accuracy: 0.8256 - val_loss: 0.6203 - val_accuracy: 0.7860
# Epoch 44/50
# 1563/1563 [==============================] - 293s 187ms/step - loss: 0.4883 - accuracy: 0.8264 - val_loss: 0.6101 - val_accuracy: 0.7921
# Epoch 45/50
# 1563/1563 [==============================] - 293s 187ms/step - loss: 0.4763 - accuracy: 0.8298 - val_loss: 0.6105 - val_accuracy: 0.7931
# Epoch 46/50
# 1563/1563 [==============================] - 286s 183ms/step - loss: 0.4721 - accuracy: 0.8311 - val_loss: 0.6259 - val_accuracy: 0.7871
# Epoch 47/50
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.4570 - accuracy: 0.8391 - val_loss: 0.6040 - val_accuracy: 0.7955
# Epoch 48/50
# 1563/1563 [==============================] - 296s 189ms/step - loss: 0.4522 - accuracy: 0.8380 - val_loss: 0.6200 - val_accuracy: 0.7877
# Epoch 49/50
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.4451 - accuracy: 0.8404 - val_loss: 0.6165 - val_accuracy: 0.7914
# Epoch 50/50
# 1563/1563 [==============================] - 293s 187ms/step - loss: 0.4341 - accuracy: 0.8448 - val_loss: 0.6161 - val_accuracy: 0.7916

# %%
# Result: After 50 epochs, the difference between training and validation accuracy is low but the training is slow as compared to the model with batch normalization.
